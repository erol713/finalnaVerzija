# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from tqdm import tqdm_notebook

# %%
df  = pd.read_csv('noviFeaturi.csv', 
                 dtype={
                     'cijena':'float', 
                     'lokacija':'category',
                     'Broj soba':'category',
                     'Godina izgradnje':'category',
                     'Primarna orjentacija':'category',
                     'stanje':'category',
                     'balkon':'category',
                     'Namjesten':'category'
                 })

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2393 entries, 0 to 2392
# Data columns (total 16 columns):
# url                     2393 non-null object
# naziv                   2393 non-null object
# cijena                  2393 non-null float64
# lokacija                2393 non-null category
# lat                     2393 non-null object
# lng                     2393 non-null object
# Kvadrata                2391 non-null float64
# Pravih Kvadrata         2391 non-null float64
# Broj soba               2393 non-null category
# Adresa                  2393 non-null object
# Godina izgradnje        2393 non-null category
# Primarna orjentacija    2393 non-null category
# stanje                  2393 non-null category
# balkon                  2393 non-null category
# dodatna kvadratura      2393 non-null float64
# Namjesten               2393 non-null category
# dtypes: category(7), float64(4), object(5)
# memory usage: 186.4+ KB

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.olx.ba/artikal/31090915/trosoban-s...
# 1  https://www.olx.ba/artikal/31109536/bauland-pr...
# 2  https://www.olx.ba/artikal/29115595/prostor-pr...
# 3  https://www.olx.ba/artikal/30908536/novogradnj...
# 4  https://www.olx.ba/artikal/30050597/prostor-pr...
#
#                                                naziv    cijena  \
# 0           Trosoban stan,82m2 Čengić Vila RENOVIRAN  178900.0
# 1      BAULAND prodaje: Trosoban/ Novogradnja/Pejton  163000.0
# 2  PROSTOR prodaje: NOVOGRADNJA trosoban stan sa ...  103350.0
# 3  NOVOGRADNJA Skenderija, dvoiposoban 52-53m2 AK...  182385.0
# 4  PROSTOR prodaje: NOVOGRADNJA Sarajevo Waves, I...  172422.0
#
#               lokacija        lat        lng  Kvadrata  Pravih Kvadrata  \
# 0        Novo Sarajevo  43.850312  18.369865      73.0             73.0
# 1               Ilidža  43.833914   18.29901      67.0             67.0
# ...

# %%
df.loc[2364]
# Out:
# url                     https://www.olx.ba/artikal/29407799/dobrinja-c...
# naziv                                               Dobrinja C5 stan 70m2
# cijena                                                             105000
# lokacija                                              Sarajevo, Novi Grad
# lat                                                               no info
# lng                                                               no info
# Kvadrata                                                               70
# Pravih Kvadrata                                                        70
# Broj soba                                                    Trosoban (3)
# Adresa                                                    Habibe Stocevic
# Godina izgradnje                                                  no info
# Primarna orjentacija                                              no info
# stanje                                                            no info
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2393 entries, 0 to 2392
# Data columns (total 16 columns):
# url                     2393 non-null object
# naziv                   2393 non-null object
# cijena                  2393 non-null float64
# lokacija                2393 non-null category
# lat                     2393 non-null object
# lng                     2393 non-null object
# Kvadrata                2391 non-null float64
# Pravih Kvadrata         2391 non-null float64
# Broj soba               2393 non-null category
# Adresa                  2393 non-null object
# Godina izgradnje        2393 non-null category
# Primarna orjentacija    2393 non-null category
# stanje                  2393 non-null category
# balkon                  2393 non-null category
# dodatna kvadratura      2393 non-null float64
# Namjesten               2393 non-null category
# dtypes: category(7), float64(4), object(5)
# memory usage: 186.4+ KB

# %%
df.dropna()
# Out:
#                                                     url  \
# 0     https://www.olx.ba/artikal/31090915/trosoban-s...
# 1     https://www.olx.ba/artikal/31109536/bauland-pr...
# 2     https://www.olx.ba/artikal/29115595/prostor-pr...
# 3     https://www.olx.ba/artikal/30908536/novogradnj...
# 4     https://www.olx.ba/artikal/30050597/prostor-pr...
# 5     https://www.olx.ba/artikal/30272731/prostor-pr...
# 6     https://www.olx.ba/artikal/31378623/novogradnj...
# 7     https://www.olx.ba/artikal/29021917/novogradnj...
# 8     https://www.olx.ba/artikal/31132068/novogradnj...
# 9     https://www.olx.ba/artikal/28879174/prostor-pr...
# 10    https://www.olx.ba/artikal/29702619/prostor-pr...
# 11    https://www.olx.ba/artikal/30265801/prostor-pr...
# 12    https://www.olx.ba/artikal/31426549/dvosoban-s...
# 13    https://www.olx.ba/artikal/22626868/stan-saraj...
# 14    https://www.olx.ba/artikal/28838865/cetverosob...
# 15    https://www.olx.ba/artikal/31153043/trosoban-s...
# ...

# %%
df.describe()
# Out:
#              cijena     Kvadrata  Pravih Kvadrata  dodatna kvadratura
# count  2.393000e+03  2391.000000      2391.000000         2393.000000
# mean   1.566854e+05    73.768561        73.943593            0.137693
# std    9.523913e+04    31.441817        31.473348            2.258196
# min    1.190000e+02     6.000000         6.000000            0.000000
# 25%    1.020000e+05    56.000000        56.000000            0.000000
# 50%    1.350000e+05    70.000000        70.000000            0.000000
# 75%    1.920000e+05    85.000000        85.000000            0.000000
# max    1.400000e+06   702.000000       702.000000           69.000000

# %%
sns.pairplot(df)
# Out:
# c:\users\hp\appdata\local\programs\python\python36\lib\site-packages\numpy\lib\function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# c:\users\hp\appdata\local\programs\python\python36\lib\site-packages\numpy\lib\function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-1a6fe1782b2f> in <module>
# ----> 1 sns.pairplot(df)
#
# c:\users\hp\appdata\local\programs\python\python36\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2105     if grid.square_grid:
#    2106         if diag_kind == "hist":
# -> 2107             grid.map_diag(plt.hist, **diag_kws)
# ...

# %%
df2 = df2[df2['cijena']<300000]
df2 = df2[df2['cijena']>30000]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a570f233160e> in <module>
# ----> 1 df2 = df2[df2['cijena']<300000]
#       2 df2 = df2[df2['cijena']>30000]
#
# NameError: name 'df2' is not defined
